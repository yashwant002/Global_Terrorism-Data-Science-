# %% [markdown]
# <a href="https://colab.research.google.com/github/yashwant002/Global_Terrorism-Data-Science-/blob/main/Global_Terrorism.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
import numpy as np
import plotly.express as px
import pycountry
import os

# %%
pip install pycountry
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycountry
#   Downloading pycountry-22.3.5.tar.gz (10.1 MB)
#      |████████████████████████████████| 10.1 MB 5.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pycountry) (57.4.0)
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (PEP 517) ... done
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681845 sha256=6b20d479a55b82e97de8dc320bf6fdca583cf895a44b5d6de06810a928fe18fa
#   Stored in directory: /root/.cache/pip/wheels/0e/06/e8/7ee176e95ea9a8a8c3b3afcb1869f20adbd42413d4611c6eb4
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-22.3.5

# %%
data = pd.read_csv("globalterrorismdb_0718dist.csv", encoding = 'ISO-8859-1')
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164            1         0      NaN
# 1    Mexico city  19.371887  -99.086624            1         0      NaN
# 2        Unknown  15.478598  120.599741            4         0      NaN
# 3         Athens  37.997490   23.762728            1         0      NaN
# 4        Fukouka  33.580412  130.396361            1         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1          0          NaN             NaN
# 1     NaN      1      1      1          0          NaN             NaN
# 2     NaN      1      1      1          0          NaN             NaN
# 3     NaN      1      1      1          0          NaN             NaN
# 4     NaN      1      1      1         -9          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0         0        1        0            1                   Assassination
# 1         0        1        0            6     Hostage Taking (Kidnapping)
# 2         0        1        0            1                   Assassination
# 3         0        1        0            3               Bombing/Explosion
# 4         0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2  gsubname2  gname3  \
# 0                              MANO-D      NaN    NaN        NaN     NaN
# 1  23rd of September Communist League      NaN    NaN        NaN     NaN
# 2                             Unknown      NaN    NaN        NaN     NaN
# 3                             Unknown      NaN    NaN        NaN     NaN
# 4                             Unknown      NaN    NaN        NaN     NaN
#
#    gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  \
# 0        NaN    NaN          0.0          NaN          NaN         0.0
# 1        NaN    NaN          0.0          NaN          NaN         0.0
# 2        NaN    NaN          0.0          NaN          NaN         0.0
# 3        NaN    NaN          0.0          NaN          NaN         0.0
# 4        NaN    NaN          0.0          NaN          NaN         0.0
#
#    nperps  nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 1     7.0       NaN      NaN        NaN           NaN     NaN         NaN
# 2     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 3     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 4     NaN       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3  claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN             NaN        NaN       13.0
# 1            NaN     NaN         NaN             NaN        NaN       13.0
# 2            NaN     NaN         NaN             NaN        NaN       13.0
# 3            NaN     NaN         NaN             NaN        NaN        6.0
# 4            NaN     NaN         NaN             NaN        NaN        8.0
#
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                     NaN        NaN
# 1       Unknown           NaN                     NaN        NaN
# 2       Unknown           NaN                     NaN        NaN
# 3    Explosives          16.0  Unknown Explosive Type        NaN
# 4    Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN       0.0         NaN            NaN        NaN         NaN
# 1       NaN       0.0         NaN            NaN        NaN         NaN
# 2       NaN       0.0         NaN            NaN        NaN         NaN
# 3       NaN       1.0         NaN            NaN        NaN         NaN
# 4       NaN       1.0         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS      0.0       0.0       0.0      0.0     NaN
# 1     PGIS      0.0       1.0       1.0      1.0     NaN
# 2     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 3     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 4     PGIS     -9.0      -9.0       1.0      1.0     NaN

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("globalterrorismdb_0718dist.csv",encoding='latin1')
df.head() #used to get the first n rows
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164            1         0      NaN
# 1    Mexico city  19.371887  -99.086624            1         0      NaN
# 2        Unknown  15.478598  120.599741            4         0      NaN
# 3         Athens  37.997490   23.762728            1         0      NaN
# 4        Fukouka  33.580412  130.396361            1         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1          0          NaN             NaN
# 1     NaN      1      1      1          0          NaN             NaN
# 2     NaN      1      1      1          0          NaN             NaN
# 3     NaN      1      1      1          0          NaN             NaN
# 4     NaN      1      1      1         -9          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0         0        1        0            1                   Assassination
# 1         0        1        0            6     Hostage Taking (Kidnapping)
# 2         0        1        0            1                   Assassination
# 3         0        1        0            3               Bombing/Explosion
# 4         0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2  gsubname2  gname3  \
# 0                              MANO-D      NaN    NaN        NaN     NaN
# 1  23rd of September Communist League      NaN    NaN        NaN     NaN
# 2                             Unknown      NaN    NaN        NaN     NaN
# 3                             Unknown      NaN    NaN        NaN     NaN
# 4                             Unknown      NaN    NaN        NaN     NaN
#
#    gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  \
# 0        NaN    NaN          0.0          NaN          NaN         0.0
# 1        NaN    NaN          0.0          NaN          NaN         0.0
# 2        NaN    NaN          0.0          NaN          NaN         0.0
# 3        NaN    NaN          0.0          NaN          NaN         0.0
# 4        NaN    NaN          0.0          NaN          NaN         0.0
#
#    nperps  nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 1     7.0       NaN      NaN        NaN           NaN     NaN         NaN
# 2     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 3     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 4     NaN       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3  claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN             NaN        NaN       13.0
# 1            NaN     NaN         NaN             NaN        NaN       13.0
# 2            NaN     NaN         NaN             NaN        NaN       13.0
# 3            NaN     NaN         NaN             NaN        NaN        6.0
# 4            NaN     NaN         NaN             NaN        NaN        8.0
#
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                     NaN        NaN
# 1       Unknown           NaN                     NaN        NaN
# 2       Unknown           NaN                     NaN        NaN
# 3    Explosives          16.0  Unknown Explosive Type        NaN
# 4    Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN       0.0         NaN            NaN        NaN         NaN
# 1       NaN       0.0         NaN            NaN        NaN         NaN
# 2       NaN       0.0         NaN            NaN        NaN         NaN
# 3       NaN       1.0         NaN            NaN        NaN         NaN
# 4       NaN       1.0         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS      0.0       0.0       0.0      0.0     NaN
# 1     PGIS      0.0       1.0       1.0      1.0     NaN
# 2     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 3     PGIS     -9.0      -9.0       1.0      1.0     NaN
# 4     PGIS     -9.0      -9.0       1.0      1.0     NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7316 entries, 0 to 7315
# Columns: 135 entries, eventid to related
# dtypes: float64(63), int64(18), object(54)
# memory usage: 7.5+ MB

# %%
df.shape
# Out:
# (7316, 135)

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_AN
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max      30.000000    85.000000   285.000000    50.000000     4.000000
#
#           property   propextent     propvalue    ishostkid     nhostkid  \
# count  7315.000000  3448.000000  2.287000e+03  7190.000000   580.000000
# mean      0.550649     3.243039  1.354194e+05     0.080668    -1.463793
# std       1.093145     0.469039  1.143578e+06     0.272343    66.295438
# min      -9.000000     2.000000 -9.900000e+01     0.000000   -99.000000
# 25%       0.000000     3.000000  1.500000e+03     0.000000     1.000000
# 50%       1.000000     3.000000  3.000000e+03     0.000000     1.000000
# 75%       1.000000     4.000000  1.500000e+04     0.000000     2.000000
# max       1.000000     4.000000  3.000000e+07     1.000000  1200.000000
#
#        nhostkidus      nhours       ndays       ransom     ransomamt  \
# count  580.000000  211.000000  185.000000  7098.000000  2.300000e+02
# mean     0.186207   -1.468009   35.929730     0.032544  6.014240e+06
# std      4.869256   15.685806   81.055942     0.177453  6.622020e+07
# min    -99.000000  -99.000000    0.000000     0.000000  0.000000e+00
# 25%      0.000000    0.000000    1.000000     0.000000  0.000000e+00
# 50%      0.000000    0.000000    5.000000     0.000000  3.400000e+04
# 75%      0.000000    0.000000   29.000000     0.000000  6.000000e+05
# max     50.000000   30.000000  752.000000     1.000000  1.000000e+09
#
#        ransomamtus    ransompaid  ransompaidus  hostkidoutcome   nreleased  \
# count          1.0  7.200000e+01           0.0      371.000000  280.000000
# mean       20000.0  1.566266e+06           NaN        2.865229    6.428571
# std            NaN  5.339688e+06           NaN        1.302037   24.729981
# min        20000.0  0.000000e+00           NaN        2.000000  -99.000000
# 25%        20000.0  0.000000e+00           NaN        2.000000    1.000000
# 50%        20000.0  8.000000e+04           NaN        2.000000    1.000000
# 75%        20000.0  7.750000e+05           NaN        4.000000    2.000000
# max        20000.0  4.100000e+07           NaN        7.000000  187.000000
#
#            INT_LOG     INT_IDEO     INT_MISC      INT_ANY
# count  7315.000000  7315.000000  7315.000000  7315.000000
# mean     -3.135885    -3.064252     0.409706    -1.596719
# std       4.423057     4.486479     0.662392     4.131260
# min      -9.000000    -9.000000    -9.000000    -9.000000
# 25%      -9.000000    -9.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     1.000000
# 75%       0.000000     0.000000     1.000000     1.000000
# max       1.000000     1.000000     1.000000     1.000000

# %%
df.isnull().sum()
# Out:
# eventid                  0
# iyear                    0
# imonth                   0
# iday                     0
# approxdate            7300
# extended                 0
# resolution            7101
# country                  0
# country_txt              0
# region                   0
# region_txt               0
# provstate               26
# city                     0
# latitude               183
# longitude              183
# specificity              0
# vicinity                 0
# location              6773
# summary               6461
# crit1                    0
# crit2                    0
# crit3                    0
# doubtterr                0
# alternative           6392
# alternative_txt       6392
# multiple                 0
# success                  0
# suicide                  0
# attacktype1              0
# attacktype1_txt          0
# attacktype2           7298
# attacktype2_txt       7298
# attacktype3           7314
# attacktype3_txt       7314
# targtype1                0
# targtype1_txt            0
# targsubtype1           419
# targsubtype1_txt       419
# corp1                 4510
# target1                 66
# natlty1                 20
# natlty1_txt             20
# targtype2             7207
# targtype2_txt         7207
# targsubtype2          7232
# targsubtype2_txt      7232
# corp2                 7231
# target2               7222
# natlty2               7222
# natlty2_txt           7222
# targtype3             7306
# targtype3_txt         7306
# targsubtype3          7309
# targsubtype3_txt      7309
# corp3                 7311
# target3               7306
# natlty3               7306
# natlty3_txt           7306
# gname                    1
# gsubname              7209
# gname2                7305
# gsubname2             7316
# gname3                7316
# gsubname3             7316
# motive                6725
# guncertain1              1
# guncertain2           7305
# guncertain3           7316
# individual               1
# nperps                5471
# nperpcap              6462
# claimed               6457
# claimmode             7101
# claimmode_txt         7101
# claim2                7309
# claimmode2            7310
# claimmode2_txt        7310
# claim3                7316
# claimmode3            7316
# claimmode3_txt        7316
# compclaim             7302
# weaptype1                1
# weaptype1_txt            1
# weapsubtype1          1389
# weapsubtype1_txt      1389
# weaptype2             6991
# weaptype2_txt         6991
# weapsubtype2          7021
# weapsubtype2_txt      7021
# weaptype3             7297
# weaptype3_txt         7297
# weapsubtype3          7299
# weapsubtype3_txt      7299
# weaptype4             7313
# weaptype4_txt         7313
# weapsubtype4          7313
# weapsubtype4_txt      7313
# weapdetail             708
# nkill                  809
# nkillus               6172
# nkillter              6171
# nwound                2043
# nwoundus              6197
# nwoundte              6244
# property                 1
# propextent            3868
# propextent_txt        3868
# propvalue             5029
# propcomment           6755
# ishostkid              126
# nhostkid              6736
# nhostkidus            6736
# nhours                7105
# ndays                 7131
# divert                7275
# kidhijcountry         6882
# ransom                 218
# ransomamt             7086
# ransomamtus           7315
# ransompaid            7244
# ransompaidus          7316
# ransomnote            7311
# hostkidoutcome        6945
# hostkidoutcome_txt    6945
# nreleased             7036
# addnotes              6690
# scite1                6461
# scite2                6575
# scite3                6818
# dbsource                 1
# INT_LOG                  1
# INT_IDEO                 1
# INT_MISC                 1
# INT_ANY                  1
# related               6847
# dtype: int64

# %%
df["nwound"] = df["nwound"].fillna(0)
df['nkill'] = df['nkill'].fillna(0)

# %%
df['Casualities'] = df['nkill'] + df['nwound']

# %%
df['city'] = df['city'].replace(['Unknown'],'Baghdad')
df

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)

# %%
df = df[['Year','Month','day','Country','State','Region','City','latitude','longitude',"Attacktype",'kill',
               'Wound','target1','summary','Group','Targettype','Weapon','motive']]

# %%
df.head()
# Out:
#    Year  Month  day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             City   latitude   longitude                      Attacktype  kill  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination   1.0
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)   0.0
# 2        Baghdad  15.478598  120.599741                   Assassination   1.0
# 3         Athens  37.997490   23.762728               Bombing/Explosion   0.0
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack   0.0
#
#    Wound                  target1 summary                               Group  \
# 0    0.0             Julio Guzman     NaN                              MANO-D
# 1    0.0  Nadine Chaval, daughter     NaN  23rd of September Communist League
# 2    0.0                 Employee     NaN                             Unknown
# 3    0.0             U.S. Embassy     NaN                             Unknown
# 4    0.0           U.S. Consulate     NaN                             Unknown
#
#                     Targettype      Weapon motive
# 0  Private Citizens & Property     Unknown    NaN
# 1      Government (Diplomatic)     Unknown    NaN
# 2          Journalists & Media     Unknown    NaN
# 3      Government (Diplomatic)  Explosives    NaN
# 4      Government (Diplomatic)  Incendiary    NaN

# %%
df.shape
# Out:
# (7316, 18)

# %%
year = df['Year'].unique()
years_count = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = year,
           y = years_count,
           palette = "tab10")
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',fontsize=20)
plt.title('Attacks In Years',fontsize=30)
plt.show()

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities By Region In Each Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()

# %%
attackAreas = df.Country.value_counts()[:10]
attackAreas
# Out:
# United Kingdom        1407
# United States         1406
# Italy                  824
# Spain                  632
# Turkey                 343
# Argentina              314
# Colombia               282
# France                 265
# West Germany (FRG)     256
# Greece                 134
# Name: Country, dtype: int64

# %%
df.Group.value_counts()[1:10]
# Out:
# Irish Republican Army (IRA)                      820
# Basque Fatherland and Freedom (ETA)              263
# Protestant extremists                            188
# Left-Wing Militants                              169
# Ulster Volunteer Force (UVF)                     164
# Red Brigades                                     124
# Black September                                  120
# Montoneros (Argentina)                           109
# Fuerzas Armadas de Liberacion Nacional (FALN)     96
# Name: Group, dtype: int64

# %%
plt.subplots(figsize=(20,10))
sns.barplot(df['Country'].value_counts()[:10].index,df['Country'].value_counts()[:10].values,palette='YlOrBr_r')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation = 50)
plt.show()

# %%
dataKill = df[['Year','kill']].groupby(['Year']).sum()
fig, ax4 = plt.subplots(figsize=(20,10))
dataKill.plot(kind='bar',alpha=0.7,ax=ax4)
plt.xticks(rotation = 50)
plt.title("People Died Due To Attack",fontsize=25)
plt.ylabel("Number of killed peope",fontsize=20)
plt.xlabel('Year',fontsize=20)
top_side = ax4.spines["top"]
top_side.set_visible(False)
right_side = ax4.spines["right"]
right_side.set_visible(False)

# %%
df['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(20,10),color='blue')
plt.xticks(rotation = 50)
plt.xlabel("City",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Top 10 most effected city",fontsize=20)
plt.show()

# %%
df['Attacktype'].value_counts().plot(kind='bar',figsize=(20,10),color='magenta')
plt.xticks(rotation = 50)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("Number of attack",fontsize=15)
plt.title("Name of attacktype",fontsize=20)
plt.show()

# %%
df[['Attacktype','kill']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['darkslateblue'])
plt.xticks(rotation=50)
plt.title("Number of killed ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
df[['Attacktype','Wound']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(20,10),color=['cyan'])
plt.xticks(rotation=50)
plt.title("Number of wounded  ",fontsize=20)
plt.ylabel('Number of people',fontsize=15)
plt.xlabel('Attack type',fontsize=15)
plt.show()

# %%
plt.subplots(figsize=(20,10))
sns.countplot(df["Targettype"],order=df['Targettype'].value_counts().index,palette="gist_heat",edgecolor=sns.color_palette("mako"));
plt.xticks(rotation=90)
plt.xlabel("Attacktype",fontsize=15)
plt.ylabel("count",fontsize=15)
plt.title("Attack per year",fontsize=20)
plt.show()

# %%
df['Group'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='green',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.ylabel("Attack number",fontsize=15)
plt.show()

# %%
df[['Group','kill']].groupby(['Group'],axis=0).sum().drop('Unknown').sort_values('kill',ascending=False).head(10).plot(kind='bar',color='yellow',figsize=(20,10))
plt.title("Top 10 terrorist group attack",fontsize=20)
plt.xlabel("terrorist group name",fontsize=15)
plt.ylabel("No of killed people",fontsize=15)
plt.show()

# %%
data=df[['Group','Country','kill']]
data=data.groupby(['Group','Country'],axis=0).sum().sort_values('kill',ascending=False).drop('Unknown').reset_index().head(10)
data
# Out:
#                                          Group         Country   kill
# 0                  Irish Republican Army (IRA)  United Kingdom  888.0
# 1                      Mujahedin-e Khalq (MEK)            Iran  448.0
# 2                 Ulster Volunteer Force (UVF)  United Kingdom  238.0
# 3                        Protestant extremists  United Kingdom  218.0
# 4                       Montoneros (Argentina)       Argentina  202.0
# 5  Sandinista National Liberation Front (FSLN)       Nicaragua  141.0
# 6          Basque Fatherland and Freedom (ETA)           Spain  132.0
# 7        Moro National Liberation Front (MNLF)     Philippines  110.0
# 8                Ulster Freedom Fighters (UFF)  United Kingdom  101.0
# 9                                 Ahmad Jibril         Lebanon   98.0

# %%
kill = df.loc[:,'kill']
print('Number of people killed by terror attack:', int(sum(kill.dropna())))
# Out:
# Number of people killed by terror attack: 5114

# %%
typeKill = df.pivot_table(columns='Attacktype', values='kill', aggfunc='sum')
typeKill
# Out:
# Attacktype  Armed Assault  Assassination  Bombing/Explosion  \
# kill               1050.0         1484.0             1568.0
#
# Attacktype  Facility/Infrastructure Attack  Hijacking  \
# kill                                 454.0      175.0
#
# Attacktype  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# kill                                      177.0                        113.0
#
# Attacktype  Unarmed Assault  Unknown
# kill                    8.0     85.0

# %%
countryKill = df.pivot_table(columns='Country', values='kill', aggfunc='sum')
countryKill
# Out:
# Country  Afghanistan  Algeria  Andorra  Angola  Argentina  Australia  Austria  \
# kill             0.0      0.0      0.0     0.0      317.0        3.0      9.0
#
# Country  Bahamas  Bangladesh  Barbados  Belgium  Bolivia  Botswana  Brazil  \
# kill         0.0         0.0      73.0      1.0      0.0       1.0     3.0
#
# Country  Brunei  Cambodia  Canada  Chad  Chile  Colombia  Costa Rica  Cyprus  \
# kill        0.0       4.0     2.0   0.0    0.0     135.0         0.0    17.0
#
# Country  Czechoslovakia  Denmark  Djibouti  Dominican Republic  \
# kill               26.0      0.0       1.0                 4.0
#
# Country  East Germany (GDR)  Ecuador  Egypt  El Salvador  Ethiopia  France  \
# kill                    1.0      4.0    4.0         42.0      34.0    43.0
#
# Country  Greece  Guatemala  Guyana  Haiti  Honduras  India  Indonesia   Iran  \
# kill      115.0       74.0     5.0    0.0       0.0    4.0        1.0  469.0
#
# Country  Iraq  Ireland  Israel  Italy  Jamaica  Japan  Jordan  Kenya  Kuwait  \
# kill     12.0     61.0   190.0  147.0      0.0    9.0    12.0   31.0     1.0
#
# Country  Lebanon  Malaysia  Malta  Mauritania  Mexico  Morocco  Mozambique  \
# kill       146.0     100.0    1.0         4.0    79.0     10.0         2.0
#
# Country  Myanmar  Namibia  Netherlands  New Zealand  Nicaragua  Nigeria  \
# kill        17.0      6.0         17.0          0.0      152.0      3.0
#
# Country  North Yemen  Pakistan  Panama  Paraguay  \
# kill             2.0      11.0     0.0       2.0
#
# Country  People's Republic of the Congo  Peru  Philippines  Poland  Portugal  \
# kill                                0.0   0.0        228.0     0.0       3.0
#
# Country  Rhodesia  Saudi Arabia  Singapore  Somalia  South Africa  \
# kill         93.0           0.0        0.0      0.0          13.0
#
# Country  South Korea  South Vietnam  South Yemen  Soviet Union  Spain  \
# kill             1.0           81.0          0.0           4.0  209.0
#
# Country  Sri Lanka  Sudan  Sweden  Switzerland  Syria  Taiwan  Tanzania  \
# kill           1.0    3.0     4.0         47.0    7.0    25.0       0.0
#
# Country  Thailand  Trinidad and Tobago  Turkey  United Arab Emirates  \
# kill         32.0                  0.0    80.0                   7.0
#
# Country  United Kingdom  United States  Uruguay  Venezuela  \
# kill             1638.0          164.0      4.0        2.0
#
# Country  West Bank and Gaza Strip  West Germany (FRG)  Western Sahara  \
# kill                          9.0                44.0             0.0
#
# Country  Yugoslavia  Zaire  Zambia
# kill            2.0    1.0     5.0
